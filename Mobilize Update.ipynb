# %%
import pandas as pd
import numpy as np
import os
import sys

# %%
# Create DataFrame from file
path = 'C:/Projects/DataCleanup/'
full_mobilize = 'Mobilize updated status.csv'
fullfile_df = pd.read_csv(path + full_mobilize, skip_blank_lines=True, dtype={'ProfileId':int}, low_memory=False)
fullfile_df.head()
# Out:
#   First Name  Last Name Profile Status Termination Reason  Active  \
# 0    Fatimah   Abdullah            New                NaN   False
# 1      Julie      Szabo            New                NaN   False
# 2      David  Barsamian            New                NaN   False
# 3      Tracy  Seelbaugh            New                NaN    True
# 4      Karen  Wlostoski            New                NaN    True
#
#                 Phone Number                 Email Address  \
# 0               000-000-0000         fabdullah_3@yahoo.com
# 1               413-770-7671         szabo.julie@yahoo.com
# 2               000-000-0000  noemail@favoritestaffing.com
# 3  724-712-4688,724-372-4466         tlseelbaugh@gmail.com
# 4               413-773-7298           sasha65@comcast.net
#
#           Street Address        City State ZIP code  EID_M WorkdayId  \
# 0  30760 eden allen road        Eden    MD    21822  19908       NaN
# 1        12 von nida ave  Pittsfield    MA     1201  19909       NaN
# ...

# %%
# Need to process files to changed Completed column to true if the line has been processed

# %%
# Out:
#        First Name  Last Name Profile Status Termination Reason  Active  \
# 0         Fatimah   Abdullah            New                NaN   False
# 1           Julie      Szabo            New                NaN   False
# 2           David  Barsamian            New                NaN   False
# 3           Tracy  Seelbaugh            New                NaN    True
# 4           Karen  Wlostoski            New                NaN    True
# ...           ...        ...            ...                ...     ...
# 384606   Chinonso       Ugwu            New                NaN    True
# 384607     Amanda      Clark            New                NaN    True
# 384608      Susan    Mohamed            New                NaN    True
# 384609      Abdul    Mubariz            New                NaN    True
# 384610     Neshon      Curry            New                NaN    True
#
#                      Phone Number                 Email Address  \
# ...

# %%
# Save as new Mobilize full file
bounced_df.to_csv('Mobilize updated status.csv')
