# %%
import pandas as pd
import numpy as np
import os
import sys
from datetime import date

# %%
master_path = 'C:/DataCleanup/Data/'
master_file = 'Master Tracking Sheet'
file_df = pd.read_excel(master_path + master_file + '.xlsx')
file_df
# Out:
#         Unnamed: 0  Unnamed: 0.1 FirstName_M LastName_M  \
# 0                0             0     Fatimah   Abdullah
# 1                1             1       Julie      Szabo
# 2                2             2       David  Barsamian
# 3                3             3       Tracy  Seelbaugh
# 4                4             4       Karen  Wlostoski
# ...            ...           ...         ...        ...
# 369057      369057        369084    Sashauna      Brown
# 369058      369058        369085       Chloe    Iverson
# 369059      369059        369086     Matthew   Hennessy
# 369060      369060        369087       Louis    Gaskins
# 369061      369061        369088       Tyler  Prestidge
#
#                             Phone_M                       email_M  \
# 0                      000-000-0000          ameenah007@yahoo.com
# 1                      413-770-7671         szabo.julie@yahoo.com
# 2                      000-000-0000  noemail@favoritestaffing.com
# ...

# %%
file_df2 = file_df.loc[file_df['Completed'] != '10/09/2021']
file_df2
# Out:
#         Unnamed: 0  Unnamed: 0.1 FirstName_M LastName_M  \
# 0                0             0     Fatimah   Abdullah
# 1                1             1       Julie      Szabo
# 2                2             2       David  Barsamian
# 3                3             3       Tracy  Seelbaugh
# 4                4             4       Karen  Wlostoski
# ...            ...           ...         ...        ...
# 369057      369057        369084    Sashauna      Brown
# 369058      369058        369085       Chloe    Iverson
# 369059      369059        369086     Matthew   Hennessy
# 369060      369060        369087       Louis    Gaskins
# 369061      369061        369088       Tyler  Prestidge
#
#                             Phone_M                       email_M  \
# 0                      000-000-0000          ameenah007@yahoo.com
# 1                      413-770-7671         szabo.julie@yahoo.com
# 2                      000-000-0000  noemail@favoritestaffing.com
# ...

# %%
# Rename old file before saving new
today = date.today()
str_today = today.strftime("%Y-%m-%d")
file_df.to_excel(master_path + master_file + str_today + ".xlsx" )

# %%
# Save file to new master tracking sheet
file_df2.to_excel(master_path + "Master Tracking Sheet.xlsx")
